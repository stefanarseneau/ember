# %%
from ember.mcmc import util, fitting

# %%
iterp, photo = util.make_interpolator(bands=["Gaia_G"], units="flam")

# %%
iterp
# Out:
# <function interpolator.atmos.spectrum.WarwickPhotometry.make_cache_2p.<locals>.cached_interp(teff, logg, av=None)>

# %%
iterp(500, 5)
# Out:
# array([-7207.80825599])
